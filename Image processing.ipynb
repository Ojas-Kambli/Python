# %%
from scipy import misc
import imageio
import matplotlib.pyplot as plt
#face=misc.face()
#imageio.imsave('capybara.jpg', face)
#plt.imshow(face)
#plt.show()
img=imageio.imread('Capybara.jpg')
plt.imshow(img)
print(img.shape)
print(img.dtype)
print(img.max())
print(img.min())
print(img.mean())
# Out:
# <ipython-input-14-f6c25a61a568>:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img=imageio.imread('Capybara.jpg')
# (339, 509, 3)
# uint8
# 255
# 0
# 106.53997175714234

# %%
# Importing Necessary Libraries
from skimage import data
from skimage.color import rgb2gray
import matplotlib.pyplot as plt

# Setting the plot size to 15,15
plt.figure(figsize=(15, 15))

# Sample Image of scikit-image package
ig = data.chelsea()
plt.subplot(1, 2, 1)

# Displaying the sample image
plt.imshow(ig)

# Converting RGB image to Monochrome
gray_img = rgb2gray(ig)
plt.subplot(1, 2, 2)

# Displaying the sample image - Monochrome
# Format
plt.imshow(gray_img, cmap="gray")

# %%
from PIL import Image , ImageEnhance
img = Image.open('Capybara.jpg')
img.show()
print(img.height)
print(img.width)
print(img.size)
print(img.format)
print(img.mode)
img1 = img.resize((900, 800))
img1.save('new_Capybara.jpg')
print(img1.size)
img.thumbnail((1000, 800))
img.save('Capybara_thumbnail.jpg')
print(img.size)
box = (150, 150, 400, 400)
cropped_lena = img.crop(box)
cropped_lena.save('cropped_Capybara.jpg')
image = Image.open('Koala.jpg')
logo = Image.open('Capybara.jpg')
image_copy = image.copy()
position = ((480), (180))
image_copy.paste(logo, position)
image_copy.save('taj_lena.png')
print(image_copy)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=509x339 at 0x7EFCA5ECDFA0>
# 339
# 509
# (509, 339)
# JPEG
# RGB
# (900, 800)
# (509, 339)
# <PIL.Image.Image image mode=RGB size=945x630 at 0x7EFCA5EA4F40>

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow
img=cv.imread("Red_Panda.jpg")
cv2_imshow(img)
b, g, r=cv.split(img)
cv2_imshow(b)
cv2_imshow(g)
cv2_imshow(r)
plt.hist(img.ravel(),256,[0,256])
plt.hist(b.ravel(),256,[0,256])
plt.hist(g.ravel(),256,[0,256])
plt.hist(r.ravel(),256,[0,256])
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=297x170 at 0x7EFC9AC542B0>
# <PIL.Image.Image image mode=L size=297x170 at 0x7EFCA6500760>
# <PIL.Image.Image image mode=L size=297x170 at 0x7EFC9A6B2AF0>
# <PIL.Image.Image image mode=L size=297x170 at 0x7EFCA6500760>

# %%
# Importing Necessary Libraries
from skimage import data
from skimage.color import rgb2gray
from skimage.color import rgb2hsv
import matplotlib.pyplot as plt

# Setting the plot size to 15,15
plt.figure(figsize=(15, 15))

# Sample Image of scikit-image package
chel = data.chelsea()
plt.subplot(1, 3, 1)

# Displaying the sample image
plt.imshow(chel)

# Converting RGB image to Monochrome
gray_chel = rgb2gray(chel)
plt.subplot(1, 3, 2)

# Displaying the sample image - Monochrome
# Format
plt.imshow(gray_chel, cmap="gray")

# Converting RGB Image to HSV Image
hsv_chel = rgb2hsv(chel)
plt.subplot(1, 3, 3)

# Displaying the sample image - HSV Format
hsv_coffee_colorbar = plt.imshow(hsv_chel)

# Adjusting colorbar to fit the size of the image
plt.colorbar(hsv_coffee_colorbar, fraction=0.046, pad=0.04)

# %%
# Importing Necessary Libraries
# Displaying the sample image - Monochrome Format
from skimage import data
from skimage import filters
from skimage.color import rgb2gray
import matplotlib.pyplot as plt

# Sample Image of scikit-image package
coffee = data.coffee()
gray_coffee = rgb2gray(coffee)

# Setting the plot size to 15,15
plt.figure(figsize=(15, 15))

for i in range(10):

  # Iterating different thresholds
  binarized_gray = (gray_coffee > i*0.1)*1
  plt.subplot(5,2,i+1)

  # Rounding of the threshold
  # value to 1 decimal point
  plt.title("Threshold: >"+str(round(i*0.1,1)))

  # Displaying the binarized image
  # of various thresholds
  plt.imshow(binarized_gray, cmap = 'gray')

plt.tight_layout()
